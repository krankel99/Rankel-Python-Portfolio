# %% [markdown]
# # HW 4-7

# %% [markdown]
# ## Step 1: Setup Environment

# %% [markdown]
# - Ensure you have spaCy and pandas installed in your Python environment.
# - Import the required libraries for working with spaCy and pandas.

# %%
import pandas as pd 
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (3.8.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (2.11.1)
# Requirement already satisfied: jinja2 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.12.14)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: wrapt in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kevin\anaconda3\envs\pandas-playground\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ------- -------------------------------- 2.4/12.8 MB 13.4 MB/s eta 0:00:01
#      ----------------- ---------------------- 5.5/12.8 MB 14.6 MB/s eta 0:00:01
#      --------------------------- ------------ 8.7/12.8 MB 14.9 MB/s eta 0:00:01
#      ----------------------------------- --- 11.8/12.8 MB 14.8 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 13.8 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ## Step 2: Load the Dataset

# %% [markdown]
# - Download the provided dataset and load it into a pandas DataFrame. HINT: The file is a .tsv, so use pd.read_csv() with the sep='\t' to read the file.
# - Examine the DataFrame to identify the columns containing company names and stock symbol.

# %%
df=pd.read_csv('stocks-1.tsv', sep='\t')
df
# Out:
#      Symbol              CompanyName                          Industry  \
# 0         A     Agilent Technologies    Life Sciences Tools & Services
# 1        AA                    Alcoa                   Metals & Mining
# 2       AAC         Ares Acquisition                   Shell Companies
# 3      AACG    ATA Creativity Global     Diversified Consumer Services
# 4      AADI          Aadi Bioscience                   Pharmaceuticals
# ...     ...                      ...                               ...
# 5874   ZWRK       Z-Work Acquisition                   Shell Companies
# 5875     ZY                 Zymergen                         Chemicals
# 5876   ZYME                Zymeworks                     Biotechnology
# 5877   ZYNE  Zynerba Pharmaceuticals                   Pharmaceuticals
# 5878   ZYXI                    Zynex  Health Care Equipment & Supplies
#
#      MarketCap
# 0       53.65B
# 1        9.25B
# 2        1.22B
# 3       90.35M
# 4      104.85M
# ...        ...
# 5874   278.88M
# 5875     1.31B
# 5876     1.50B
# 5877   184.39M
# 5878   438.33M
#
# [5879 rows x 4 columns]

# %% [markdown]
# ## Step 3: Extract Data for Patterns

# %% [markdown]
# - Extract unique company names and stock symbol from the appropriate columns of the DataFrame.
# - Create patterns for each company and stock symbol, ensuring they are properly formatted to be recognized by spaCy's EntityRuler.
# - DO NOT manually input individual company stocks to create your patterns. Find an automated solution in case your DataFrame ever gets updated. HINT: Think for-loops.

# %%
# this extracts the unique company names and stock symbols
unique_companies=df['CompanyName'].unique()
unique_symbols=df['Symbol'].unique()

# this create empty lists for patterns
company_patterns=[]
symbol_patterns=[]

# this loops through the companies and creates patterns
for name in unique_companies:
    pattern={'label': 'ORG', 'pattern': name}
    company_patterns.append(pattern)

# this loops through the symbols and creates patterns
for symbol in unique_symbols:
    pattern={'label': 'STOCK', 'pattern': symbol}
    symbol_patterns.append(pattern)

# this combines both pattern lists
all_patterns=company_patterns+symbol_patterns
all_patterns
# Out:
# [{'label': 'ORG', 'pattern': 'Agilent Technologies'},
#  {'label': 'ORG', 'pattern': 'Alcoa'},
#  {'label': 'ORG', 'pattern': 'Ares Acquisition'},
#  {'label': 'ORG', 'pattern': 'ATA Creativity Global'},
#  {'label': 'ORG', 'pattern': 'Aadi Bioscience'},
#  {'label': 'ORG', 'pattern': 'Arlington Asset Investment'},
#  {'label': 'ORG', 'pattern': 'American Airlines'},
#  {'label': 'ORG', 'pattern': 'Altisource Asset Management'},
#  {'label': 'ORG', 'pattern': 'Atlantic American'},
#  {'label': 'ORG', 'pattern': "The Aaron's Company"},
#  {'label': 'ORG', 'pattern': 'Applied Optoelectronics'},
#  {'label': 'ORG', 'pattern': 'AAON, Inc.'},
#  {'label': 'ORG', 'pattern': 'Advance Auto Parts'},
#  {'label': 'ORG', 'pattern': 'Apple'},
#  {'label': 'ORG', 'pattern': 'Accelerate Acquisition'},
#  {'label': 'ORG', 'pattern': 'American Assets Trust'},
#  {'label': 'ORG', 'pattern': 'Autoscope Technologies'},
#  {'label': 'ORG', 'pattern': 'Almaden Minerals'},
#  {'label': 'ORG', 'pattern': 'Atlas Air Worldwide Holdings'},
#  {'label': 'ORG', 'pattern': 'AllianceBernstein'},
#  {'label': 'ORG', 'pattern': 'ABB Ltd.'},
#  {'label': 'ORG', 'pattern': 'AbbVie'},
#  {'label': 'ORG', 'pattern': 'AmerisourceBergen'},
#  {'label': 'ORG', 'pattern': 'Ameris Bancorp'},
#  {'label': 'ORG', 'pattern': 'AbCellera Biologics'},
#  {'label': 'ORG', 'pattern': 'Abcam PLC'},
#  {'label': 'ORG', 'pattern': 'Abeona Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Ambev'},
#  {'label': 'ORG', 'pattern': 'Asbury Automotive Group'},
#  {'label': 'ORG', 'pattern': 'ABG Acquisition I'},
#  {'label': 'ORG', 'pattern': 'ARCA biopharma'},
#  {'label': 'ORG', 'pattern': 'ABM Industries'},
#  {'label': 'ORG', 'pattern': 'Abiomed'},
#  {'label': 'ORG', 'pattern': 'Airbnb'},
#  {'label': 'ORG', 'pattern': 'Acumen Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Arbor Realty Trust'},
#  {'label': 'ORG', 'pattern': 'Absci'},
#  {'label': 'ORG', 'pattern': 'Absolute Software'},
#  {'label': 'ORG', 'pattern': 'Abbott Laboratories'},
#  {'label': 'ORG', 'pattern': 'Allegiance Bancshares'},
#  {'label': 'ORG', 'pattern': 'Arbutus Biopharma'},
#  {'label': 'ORG', 'pattern': 'ABVC BioPharma'},
#  {'label': 'ORG', 'pattern': 'Associated Capital Group'},
#  {'label': 'ORG', 'pattern': 'Arcosa'},
#  {'label': 'ORG', 'pattern': 'ACADIA Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Atlantic Coastal Acquisition'},
#  {'label': 'ORG', 'pattern': 'Aurora Cannabis'},
#  {'label': 'ORG', 'pattern': 'Ace Global Business Acquisition'},
#  {'label': 'ORG', 'pattern': 'Atlantic Capital Bancshares'},
#  {'label': 'ORG', 'pattern': 'American Campus Communities'},
#  {'label': 'ORG', 'pattern': 'Accolade'},
#  {'label': 'ORG', 'pattern': 'ACCO Brands'},
#  {'label': 'ORG', 'pattern': 'Accel Entertainment'},
#  {'label': 'ORG', 'pattern': 'Acer Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Adicet Bio'},
#  {'label': 'ORG', 'pattern': 'ACE Convergence Acquisition'},
#  {'label': 'ORG', 'pattern': 'Arch Capital Group'},
#  {'label': 'ORG', 'pattern': 'Aluminum Corporation of China'},
#  {'label': 'ORG', 'pattern': 'Acadia Healthcare Company'},
#  {'label': 'ORG', 'pattern': 'Achilles Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Achieve Life Sciences'},
#  {'label': 'ORG', 'pattern': 'Albertsons Companies'},
#  {'label': 'ORG', 'pattern': 'Atlas Crest Investment'},
#  {'label': 'ORG', 'pattern': 'Atlas Crest Investment II'},
#  {'label': 'ORG', 'pattern': 'AC Immune'},
#  {'label': 'ORG', 'pattern': 'ACI Worldwide'},
#  {'label': 'ORG', 'pattern': 'Ackrell SPAC Partners I'},
#  {'label': 'ORG', 'pattern': 'Axcelis Technologies'},
#  {'label': 'ORG', 'pattern': 'Aecom'},
#  {'label': 'ORG', 'pattern': 'ACM Research'},
#  {'label': 'ORG', 'pattern': 'Accenture'},
#  {'label': 'ORG', 'pattern': 'ACNB Corporation'},
#  {'label': 'ORG', 'pattern': 'Acorda Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Independence Holdings'},
#  {'label': 'ORG', 'pattern': 'ACRES Commercial Realty'},
#  {'label': 'ORG', 'pattern': 'Ares Commercial Real Estate'},
#  {'label': 'ORG', 'pattern': 'Acropolis Infrastructure Acquisition'},
#  {'label': 'ORG', 'pattern': 'Aclaris Therapeutics'},
#  {'label': 'ORG', 'pattern': 'AcelRx Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Acasti Pharma'},
#  {'label': 'ORG', 'pattern': 'Arclight Clean Transition II'},
#  {'label': 'ORG', 'pattern': 'Acacia Research'},
#  {'label': 'ORG', 'pattern': 'Acme United'},
#  {'label': 'ORG', 'pattern': 'ACV Auctions'},
#  {'label': 'ORG', 'pattern': 'Acurx Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'AeroCentury'},
#  {'label': 'ORG', 'pattern': 'Adagene'},
#  {'label': 'ORG', 'pattern': 'Adaptimmune Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Adobe'},
#  {'label': 'ORG', 'pattern': 'Agree Realty'},
#  {'label': 'ORG', 'pattern': 'ADC Therapeutics SA'},
#  {'label': 'ORG', 'pattern': '26 Capital Acquisition'},
#  {'label': 'ORG', 'pattern': 'Advanced Emissions Solutions'},
#  {'label': 'ORG', 'pattern': 'Adit EdTech Acquisition'},
#  {'label': 'ORG', 'pattern': 'Aldel Financial'},
#  {'label': 'ORG', 'pattern': 'Adagio Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Analog Devices'},
#  {'label': 'ORG', 'pattern': 'Adial Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Archer Daniels Midland'},
#  {'label': 'ORG', 'pattern': 'ADMA Biologics'},
#  {'label': 'ORG', 'pattern': 'Adamis Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Adamas Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Advent Technologies'},
#  {'label': 'ORG', 'pattern': 'Adient'},
#  {'label': 'ORG', 'pattern': 'Edoc Acquisition'},
#  {'label': 'ORG', 'pattern': 'Automatic Data Processing'},
#  {'label': 'ORG', 'pattern': 'Adaptive Biotechnologies'},
#  {'label': 'ORG', 'pattern': 'Adara Acquisition'},
#  {'label': 'ORG', 'pattern': 'Alliance Data Systems'},
#  {'label': 'ORG', 'pattern': 'Autodesk'},
#  {'label': 'ORG', 'pattern': 'ADT Inc.'},
#  {'label': 'ORG', 'pattern': 'ADTRAN, Inc.'},
#  {'label': 'ORG', 'pattern': 'Aditx Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Addus HomeCare'},
#  {'label': 'ORG', 'pattern': 'Advantage Solutions'},
#  {'label': 'ORG', 'pattern': 'Adverum Biotechnologies'},
#  {'label': 'ORG', 'pattern': 'Addex Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Advaxis'},
#  {'label': 'ORG', 'pattern': 'Adams Resources & Energy'},
#  {'label': 'ORG', 'pattern': 'Authentic Equity Acquisition'},
#  {'label': 'ORG', 'pattern': 'Ameren'},
#  {'label': 'ORG', 'pattern': 'Aegon'},
#  {'label': 'ORG', 'pattern': 'Antelope Enterprise Holdings'},
#  {'label': 'ORG', 'pattern': 'Aehr Test Systems'},
#  {'label': 'ORG', 'pattern': 'Alset Ehome International'},
#  {'label': 'ORG', 'pattern': 'Advanced Energy Industries'},
#  {'label': 'ORG', 'pattern': 'American Equity Investment Life'},
#  {'label': 'ORG', 'pattern': 'Agnico Eagle Mines'},
#  {'label': 'ORG', 'pattern': 'Aethlon Medical'},
#  {'label': 'ORG', 'pattern': 'Aenza'},
#  {'label': 'ORG', 'pattern': 'American Eagle Outfitters'},
#  {'label': 'ORG', 'pattern': 'American Electric Power'},
#  {'label': 'ORG', 'pattern': 'AerCap Holdings'},
#  {'label': 'ORG', 'pattern': 'Aerie Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'AES Corporation'},
#  {'label': 'ORG', 'pattern': 'Allied Esports Entertainment'},
#  {'label': 'ORG', 'pattern': 'Aeva Technologies'},
#  {'label': 'ORG', 'pattern': 'ADDvantage Technologies Group'},
#  {'label': 'ORG', 'pattern': 'AudioEye'},
#  {'label': 'ORG', 'pattern': 'AEterna Zentaris'},
#  {'label': 'ORG', 'pattern': 'AF Acquisition'},
#  {'label': 'ORG', 'pattern': 'Affinity Bancshares'},
#  {'label': 'ORG', 'pattern': 'AFC Gamma'},
#  {'label': 'ORG', 'pattern': 'American Financial Group'},
#  {'label': 'ORG', 'pattern': 'Armstrong Flooring'},
#  {'label': 'ORG', 'pattern': 'Acutus Medical'},
#  {'label': 'ORG', 'pattern': 'American Finance Trust'},
#  {'label': 'ORG', 'pattern': 'Aflac'},
#  {'label': 'ORG', 'pattern': 'Affimed N.V.'},
#  {'label': 'ORG', 'pattern': 'Affirm Holdings'},
#  {'label': 'ORG', 'pattern': 'Afya'},
#  {'label': 'ORG', 'pattern': 'First Majestic Silver'},
#  {'label': 'ORG', 'pattern': 'African Gold Acquisition'},
#  {'label': 'ORG', 'pattern': 'AGBA Acquisition'},
#  {'label': 'ORG', 'pattern': 'Altimeter Growth Corp.'},
#  {'label': 'ORG', 'pattern': 'Altimeter Growth 2'},
#  {'label': 'ORG', 'pattern': 'AGCO Corporation'},
#  {'label': 'ORG', 'pattern': 'AgeX Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Agenus'},
#  {'label': 'ORG', 'pattern': 'AgroFresh Solutions'},
#  {'label': 'ORG', 'pattern': 'Agrify'},
#  {'label': 'ORG', 'pattern': 'Agile Growth'},
#  {'label': 'ORG', 'pattern': 'Alamos Gold'},
#  {'label': 'ORG', 'pattern': 'AgileThought'},
#  {'label': 'ORG', 'pattern': 'Agios Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Agilon Health'},
#  {'label': 'ORG', 'pattern': 'Aeglea Biotherapeutics'},
#  {'label': 'ORG', 'pattern': 'Federal Agricultural Mortgage'},
#  {'label': 'ORG', 'pattern': 'AGM Group Holdings'},
#  {'label': 'ORG', 'pattern': 'AGNC Investment'},
#  {'label': 'ORG', 'pattern': 'Assured Guaranty'},
#  {'label': 'ORG', 'pattern': 'Avangrid'},
#  {'label': 'ORG', 'pattern': 'AgriFORCE Growing Systems'},
#  {'label': 'ORG', 'pattern': 'Adecoagro'},
#  {'label': 'ORG', 'pattern': 'Agile Therapeutics'},
#  {'label': 'ORG', 'pattern': 'PlayAGS'},
#  {'label': 'ORG', 'pattern': 'Applied Genetic Technologies'},
#  {'label': 'ORG', 'pattern': 'Agiliti'},
#  {'label': 'ORG', 'pattern': 'Argan'},
#  {'label': 'ORG', 'pattern': 'Agilysys'},
#  {'label': 'ORG', 'pattern': 'AdaptHealth'},
#  {'label': 'ORG', 'pattern': 'Armada Hoffler Properties'},
#  {'label': 'ORG', 'pattern': 'Allied Healthcare Products'},
#  {'label': 'ORG', 'pattern': 'Ashford Hospitality Trust'},
#  {'label': 'ORG', 'pattern': 'C3.ai'},
#  {'label': 'ORG', 'pattern': 'American International Group'},
#  {'label': 'ORG', 'pattern': 'Aesthetic Medical International'},
#  {'label': 'ORG', 'pattern': 'Senmiao Technology'},
#  {'label': 'ORG', 'pattern': 'AIkido Pharma'},
#  {'label': 'ORG', 'pattern': 'AIM ImmunoTech'},
#  {'label': 'ORG', 'pattern': 'Altra Industrial Motion'},
#  {'label': 'ORG', 'pattern': 'Albany International'},
#  {'label': 'ORG', 'pattern': 'Ashford'},
#  {'label': 'ORG', 'pattern': 'Apollo Investment'},
#  {'label': 'ORG', 'pattern': 'AAR Corp.'},
#  {'label': 'ORG', 'pattern': 'Apartment Income REIT'},
#  {'label': 'ORG', 'pattern': 'Airgain'},
#  {'label': 'ORG', 'pattern': 'Air Industries Group'},
#  {'label': 'ORG', 'pattern': 'Air T'},
#  {'label': 'ORG', 'pattern': 'Applied Industrial Technologies'},
#  {'label': 'ORG', 'pattern': 'Aimco'},
#  {'label': 'ORG', 'pattern': 'Assurant'},
#  {'label': 'ORG', 'pattern': 'Arthur J. Gallagher'},
#  {'label': 'ORG', 'pattern': 'Aerojet Rocketdyne'},
#  {'label': 'ORG', 'pattern': 'Great Ajax'},
#  {'label': 'ORG', 'pattern': 'Akamai Technologies'},
#  {'label': 'ORG', 'pattern': 'Akebia Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Sports Ventures Acquisition'},
#  {'label': 'ORG', 'pattern': 'Embotelladora Andina'},
#  {'label': 'ORG', 'pattern': 'Acadia Realty Trust'},
#  {'label': 'ORG', 'pattern': 'Akero Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Akoustis Technologies'},
#  {'label': 'ORG', 'pattern': 'Akari Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Akumin'},
#  {'label': 'ORG', 'pattern': 'Akouos'},
#  {'label': 'ORG', 'pattern': 'Akoya Biosciences'},
#  {'label': 'ORG', 'pattern': 'Air Lease Corporation'},
#  {'label': 'ORG', 'pattern': 'Alberton Acquisition'},
#  {'label': 'ORG', 'pattern': 'Albemarle'},
#  {'label': 'ORG', 'pattern': 'Albireo Pharma'},
#  {'label': 'ORG', 'pattern': 'Alcon'},
#  {'label': 'ORG', 'pattern': 'AltC Acquisition'},
#  {'label': 'ORG', 'pattern': 'Alico, Inc.'},
#  {'label': 'ORG', 'pattern': 'Aldeyra Therapeutics'},
#  {'label': 'ORG', 'pattern': 'ALLETE, Inc.'},
#  {'label': 'ORG', 'pattern': 'Alector'},
#  {'label': 'ORG', 'pattern': 'Alexander & Baldwin'},
#  {'label': 'ORG', 'pattern': 'ALFI'},
#  {'label': 'ORG', 'pattern': 'Alamo Group'},
#  {'label': 'ORG', 'pattern': 'Allegro MicroSystems'},
#  {'label': 'ORG', 'pattern': 'Align Technology'},
#  {'label': 'ORG', 'pattern': 'Aligos Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Allegiant Travel'},
#  {'label': 'ORG', 'pattern': 'Alignment Healthcare'},
#  {'label': 'ORG', 'pattern': 'Alimera Sciences'},
#  {'label': 'ORG', 'pattern': 'Alight'},
#  {'label': 'ORG', 'pattern': 'ALJ Regional Holdings'},
#  {'label': 'ORG', 'pattern': 'Alaska Air Group'},
#  {'label': 'ORG', 'pattern': 'Alkermes'},
#  {'label': 'ORG', 'pattern': 'Alkami Technology'},
#  {'label': 'ORG', 'pattern': 'Allstate'},
#  {'label': 'ORG', 'pattern': 'Allegion'},
#  {'label': 'ORG', 'pattern': 'Allakos'},
#  {'label': 'ORG', 'pattern': 'Allogene Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Allot Ltd.'},
#  {'label': 'ORG', 'pattern': 'Ally Financial'},
#  {'label': 'ORG', 'pattern': 'Allena Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Alnylam Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'AstroNova'},
#  {'label': 'ORG', 'pattern': 'Alpine Immune Sciences'},
#  {'label': 'ORG', 'pattern': 'Alarm.com'},
#  {'label': 'ORG', 'pattern': 'Aileron Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Alerus Financial'},
#  {'label': 'ORG', 'pattern': 'Allison Transmission Holdings'},
#  {'label': 'ORG', 'pattern': 'Altimmune'},
#  {'label': 'ORG', 'pattern': 'Altabancorp'},
#  {'label': 'ORG', 'pattern': 'Alta Equipment Group'},
#  {'label': 'ORG', 'pattern': 'Altus Midstream'},
#  {'label': 'ORG', 'pattern': 'Alto Ingredients'},
#  {'label': 'ORG', 'pattern': 'Altair Engineering'},
#  {'label': 'ORG', 'pattern': 'Altitude Acquisition'},
#  {'label': 'ORG', 'pattern': 'Autoliv'},
#  {'label': 'ORG', 'pattern': 'AlloVir'},
#  {'label': 'ORG', 'pattern': "Alexander's"},
#  {'label': 'ORG', 'pattern': 'ALX Oncology Holdings'},
#  {'label': 'ORG', 'pattern': 'Alithya Group'},
#  {'label': 'ORG', 'pattern': 'Alzamend Neuro'},
#  {'label': 'ORG', 'pattern': 'Antero Midstream'},
#  {'label': 'ORG', 'pattern': 'Amalgamated Bank'},
#  {'label': 'ORG', 'pattern': 'Ambrx Biopharma'},
#  {'label': 'ORG', 'pattern': 'American Acquisition Opportunity'},
#  {'label': 'ORG', 'pattern': 'Applied Materials'},
#  {'label': 'ORG', 'pattern': 'Ambarella'},
#  {'label': 'ORG', 'pattern': 'Ambac Financial Group'},
#  {'label': 'ORG', 'pattern': 'Ambow Education Holding'},
#  {'label': 'ORG', 'pattern': 'Ardagh MP USA'},
#  {'label': 'ORG', 'pattern': 'AMC Entertainment'},
#  {'label': 'ORG', 'pattern': 'Amcor'},
#  {'label': 'ORG', 'pattern': 'AMC Networks'},
#  {'label': 'ORG', 'pattern': 'Advanced Micro Devices'},
#  {'label': 'ORG', 'pattern': 'AMETEK, Inc.'},
#  {'label': 'ORG', 'pattern': 'Amedisys'},
#  {'label': 'ORG', 'pattern': 'Apollo Medical Holdings'},
#  {'label': 'ORG', 'pattern': 'Affiliated Managers Group'},
#  {'label': 'ORG', 'pattern': 'Amgen'},
#  {'label': 'ORG', 'pattern': 'American Homes 4 Rent'},
#  {'label': 'ORG', 'pattern': 'Amplitude Healthcare Acquisition'},
#  {'label': 'ORG', 'pattern': 'AssetMark Financial'},
#  {'label': 'ORG', 'pattern': 'Amkor Technology'},
#  {'label': 'ORG', 'pattern': 'AMN Healthcare Services'},
#  {'label': 'ORG', 'pattern': 'American National Bankshares'},
#  {'label': 'ORG', 'pattern': 'Allied Motion Technologies'},
#  {'label': 'ORG', 'pattern': 'America Movil'},
#  {'label': 'ORG', 'pattern': 'Ameriprise Financial'},
#  {'label': 'ORG', 'pattern': 'Ampio Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'AmpliTech Group'},
#  {'label': 'ORG', 'pattern': 'Amphastar Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Advanced Merger Partners'},
#  {'label': 'ORG', 'pattern': 'Amplify Energy'},
#  {'label': 'ORG', 'pattern': 'Alpha Metallurgical Resources'},
#  {'label': 'ORG', 'pattern': 'Ameresco'},
#  {'label': 'ORG', 'pattern': 'A-Mark Precious Metals'},
#  {'label': 'ORG', 'pattern': 'Amarin'},
#  {'label': 'ORG', 'pattern': 'Amyris'},
#  {'label': 'ORG', 'pattern': 'Amneal Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'American Shared Hospital Services'},
#  {'label': 'ORG', 'pattern': 'American Superconductor'},
#  {'label': 'ORG', 'pattern': 'AMERISAFE, Inc.'},
#  {'label': 'ORG', 'pattern': 'Amesite'},
#  {'label': 'ORG', 'pattern': 'American Software'},
#  {'label': 'ORG', 'pattern': 'American Tower'},
#  {'label': 'ORG', 'pattern': 'Amerant Bancorp'},
#  {'label': 'ORG', 'pattern': 'Applied Molecular Transport'},
#  {'label': 'ORG', 'pattern': 'Aemetis'},
#  {'label': 'ORG', 'pattern': 'American Woodmark'},
#  {'label': 'ORG', 'pattern': 'Amwell'},
#  {'label': 'ORG', 'pattern': 'Amryt Pharma'},
#  {'label': 'ORG', 'pattern': 'Amazon'},
#  {'label': 'ORG', 'pattern': 'AutoNation'},
#  {'label': 'ORG', 'pattern': 'AnaptysBio'},
#  {'label': 'ORG', 'pattern': 'Arctos NorthStar Acquisition'},
#  {'label': 'ORG', 'pattern': 'American National Insurance'},
#  {'label': 'ORG', 'pattern': 'Andersons'},
#  {'label': 'ORG', 'pattern': 'Anebulo Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Arista Networks'},
#  {'label': 'ORG', 'pattern': 'Abercrombie & Fitch'},
#  {'label': 'ORG', 'pattern': 'ANGI Homeservices'},
#  {'label': 'ORG', 'pattern': 'Angion Biomedica'},
#  {'label': 'ORG', 'pattern': 'AngioDynamics'},
#  {'label': 'ORG', 'pattern': 'Anika Therapeutics'},
#  {'label': 'ORG', 'pattern': 'ANI Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Anixa Biosciences'},
#  {'label': 'ORG', 'pattern': 'Annexon Biosciences'},
#  {'label': 'ORG', 'pattern': 'AnPac Bio-Medical Science'},
#  {'label': 'ORG', 'pattern': 'ANSYS, Inc.'},
#  {'label': 'ORG', 'pattern': 'AirNet Technology'},
#  {'label': 'ORG', 'pattern': 'Anthem'},
#  {'label': 'ORG', 'pattern': 'Annovis Bio'},
#  {'label': 'ORG', 'pattern': 'Sphere 3D'},
#  {'label': 'ORG', 'pattern': 'Anzu Special Acquisition I'},
#  {'label': 'ORG', 'pattern': 'Angel Oak Mortgage'},
#  {'label': 'ORG', 'pattern': 'Aon plc'},
#  {'label': 'ORG', 'pattern': 'A. O. Smith'},
#  {'label': 'ORG', 'pattern': 'Alpha & Omega Semiconductor'},
#  {'label': 'ORG', 'pattern': 'American Outdoor Brands'},
#  {'label': 'ORG', 'pattern': 'Ampco-Pittsburgh'},
#  {'label': 'ORG', 'pattern': 'Apache'},
#  {'label': 'ORG', 'pattern': 'Artisan Partners Asset Management'},
#  {'label': 'ORG', 'pattern': 'Air Products & Chemicals'},
#  {'label': 'ORG', 'pattern': 'Applied DNA Sciences'},
#  {'label': 'ORG', 'pattern': 'American Public Education'},
#  {'label': 'ORG', 'pattern': 'Apollo Endosurgery'},
#  {'label': 'ORG', 'pattern': 'APi Group'},
#  {'label': 'ORG', 'pattern': 'Apollo Strategic Growth Capital II'},
#  {'label': 'ORG', 'pattern': 'Amphenol'},
#  {'label': 'ORG', 'pattern': 'Agora'},
#  {'label': 'ORG', 'pattern': 'Apple Hospitality REIT'},
#  {'label': 'ORG', 'pattern': 'Apellis Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Applied Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Aptorum Group'},
#  {'label': 'ORG', 'pattern': 'Apollo Global Management'},
#  {'label': 'ORG', 'pattern': 'Apogee Enterprises'},
#  {'label': 'ORG', 'pattern': 'Cellect Biotechnology'},
#  {'label': 'ORG', 'pattern': 'Applovin'},
#  {'label': 'ORG', 'pattern': 'AppFolio'},
#  {'label': 'ORG', 'pattern': 'AppHarvest'},
#  {'label': 'ORG', 'pattern': 'Appian Corporation'},
#  {'label': 'ORG', 'pattern': 'Digital Turbine'},
#  {'label': 'ORG', 'pattern': 'Apria'},
#  {'label': 'ORG', 'pattern': 'Aprea Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Blue Apron'},
#  {'label': 'ORG', 'pattern': 'Apollo Strategic Growth Capital'},
#  {'label': 'ORG', 'pattern': 'Alpha Pro Tech'},
#  {'label': 'ORG', 'pattern': 'Aptose Biosciences'},
#  {'label': 'ORG', 'pattern': 'Preferred Apartment Communities'},
#  {'label': 'ORG', 'pattern': 'Aptiv'},
#  {'label': 'ORG', 'pattern': 'Aptinyx'},
#  {'label': 'ORG', 'pattern': 'Aptevo Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Asia Pacific Wire & Cable'},
#  {'label': 'ORG', 'pattern': 'Apyx Medical'},
#  {'label': 'ORG', 'pattern': 'AquaBounty Technologies'},
#  {'label': 'ORG', 'pattern': 'Aqua Metals'},
#  {'label': 'ORG', 'pattern': 'Algonquin Power & Utilities'},
#  {'label': 'ORG', 'pattern': 'Aquestive Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Evoqua Water Technologies'},
#  {'label': 'ORG', 'pattern': 'Antero Resources'},
#  {'label': 'ORG', 'pattern': 'Aravive'},
#  {'label': 'ORG', 'pattern': 'Accuray'},
#  {'label': 'ORG', 'pattern': 'Aequi Acquisition'},
#  {'label': 'ORG', 'pattern': 'ARC Document Solutions'},
#  {'label': 'ORG', 'pattern': 'ArcBest'},
#  {'label': 'ORG', 'pattern': 'Ares Capital'},
#  {'label': 'ORG', 'pattern': 'Arco Platform'},
#  {'label': 'ORG', 'pattern': 'Arch Coal'},
#  {'label': 'ORG', 'pattern': 'Arcos Dorados Holdings'},
#  {'label': 'ORG', 'pattern': 'Arcturus Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Ardagh Group SA'},
#  {'label': 'ORG', 'pattern': 'Aridis Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Ardelyx'},
#  {'label': 'ORG', 'pattern': 'Alexandria Real Estate Equities'},
#  {'label': 'ORG', 'pattern': 'American Resources'},
#  {'label': 'ORG', 'pattern': 'Ares Management'},
#  {'label': 'ORG', 'pattern': 'Argo Group International'},
#  {'label': 'ORG', 'pattern': 'Argenx SE'},
#  {'label': 'ORG', 'pattern': 'Apollo Commercial Real Estate Finance'},
#  {'label': 'ORG', 'pattern': 'ARKO'},
#  {'label': 'ORG', 'pattern': 'Ark Restaurants'},
#  {'label': 'ORG', 'pattern': 'American Realty Investors'},
#  {'label': 'ORG', 'pattern': 'Arlo Technologies'},
#  {'label': 'ORG', 'pattern': 'Alliance Resource Partners'},
#  {'label': 'ORG', 'pattern': 'Aramark'},
#  {'label': 'ORG', 'pattern': 'Armata Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Arena Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Arconic'},
#  {'label': 'ORG', 'pattern': 'Archrock'},
#  {'label': 'ORG', 'pattern': 'Arrow Financial'},
#  {'label': 'ORG', 'pattern': 'Arqit Quantum'},
#  {'label': 'ORG', 'pattern': 'Arcutis Biotherapeutics'},
#  {'label': 'ORG', 'pattern': 'ARMOUR Residential REIT'},
#  {'label': 'ORG', 'pattern': 'Arrowroot Acquisition'},
#  {'label': 'ORG', 'pattern': 'Array Technologies'},
#  {'label': 'ORG', 'pattern': 'Artisan Acquisition'},
#  {'label': 'ORG', 'pattern': 'Artelo Biosciences'},
#  {'label': 'ORG', 'pattern': 'Artesian Resources'},
#  {'label': 'ORG', 'pattern': "Art's-Way Manufacturing"},
#  {'label': 'ORG', 'pattern': 'Arrival'},
#  {'label': 'ORG', 'pattern': 'Arvinas'},
#  {'label': 'ORG', 'pattern': 'Arrow Electronics'},
#  {'label': 'ORG', 'pattern': 'Arrowhead Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'ARYA Sciences Acquisition IV'},
#  {'label': 'ORG', 'pattern': 'Arya Sciences Acquisition V'},
#  {'label': 'ORG', 'pattern': 'ASA Gold And Precious Metals'},
#  {'label': 'ORG', 'pattern': 'Sendas Distribuidora'},
#  {'label': 'ORG', 'pattern': 'Asana'},
#  {'label': 'ORG', 'pattern': 'Atlantic Street Acquisition'},
#  {'label': 'ORG', 'pattern': 'Astrea Acquisition'},
#  {'label': 'ORG', 'pattern': 'Associated Banc-Corp'},
#  {'label': 'ORG', 'pattern': 'Ardmore Shipping'},
#  {'label': 'ORG', 'pattern': 'ASGN Incorporated'},
#  {'label': 'ORG', 'pattern': 'Ashland'},
#  {'label': 'ORG', 'pattern': 'AdvanSix'},
#  {'label': 'ORG', 'pattern': 'AerSale'},
#  {'label': 'ORG', 'pattern': 'ASLAN Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Avino Silver & Gold Mines'},
#  {'label': 'ORG', 'pattern': 'Assembly Biosciences'},
#  {'label': 'ORG', 'pattern': 'ASML Holding'},
#  {'label': 'ORG', 'pattern': 'Ascendis Pharma A/S'},
#  {'label': 'ORG', 'pattern': 'Academy Sports and Outdoors'},
#  {'label': 'ORG', 'pattern': 'Alpha Capital Acquisition'},
#  {'label': 'ORG', 'pattern': 'Aspen Aerogels'},
#  {'label': 'ORG', 'pattern': 'Altisource Portfolio Solutions'},
#  {'label': 'ORG', 'pattern': 'Aspen Group'},
#  {'label': 'ORG', 'pattern': 'Grupo Aeroportuario del Sureste'},
#  {'label': 'ORG', 'pattern': 'Assertio Therapeutics'},
#  {'label': 'ORG', 'pattern': 'AmeriServ Financial'},
#  {'label': 'ORG', 'pattern': 'Astrotech'},
#  {'label': 'ORG', 'pattern': 'Astec Industries'},
#  {'label': 'ORG', 'pattern': 'Astra Space'},
#  {'label': 'ORG', 'pattern': 'AST SpaceMobile'},
#  {'label': 'ORG', 'pattern': 'Asure Software'},
#  {'label': 'ORG', 'pattern': 'ASE Technology'},
#  {'label': 'ORG', 'pattern': 'Asensus Surgical'},
#  {'label': 'ORG', 'pattern': 'Amtech Systems'},
#  {'label': 'ORG', 'pattern': 'Austerlitz Acquisition II'},
#  {'label': 'ORG', 'pattern': 'Americas Technology Acquisition'},
#  {'label': 'ORG', 'pattern': 'ATAI Life Sciences'},
#  {'label': 'ORG', 'pattern': 'Altimar Acquisition III'},
#  {'label': 'ORG', 'pattern': 'America First Multifamily Investors'},
#  {'label': 'ORG', 'pattern': 'Atotech'},
#  {'label': 'ORG', 'pattern': 'Atlas Corp.'},
#  {'label': 'ORG', 'pattern': 'Atlas Technical Consultants'},
#  {'label': 'ORG', 'pattern': 'Alphatec Holdings'},
#  {'label': 'ORG', 'pattern': 'A10 Networks'},
#  {'label': 'ORG', 'pattern': 'Aterian'},
#  {'label': 'ORG', 'pattern': 'Anterix'},
#  {'label': 'ORG', 'pattern': 'Adtalem Global Education'},
#  {'label': 'ORG', 'pattern': 'Athene Holding'},
#  {'label': 'ORG', 'pattern': 'Athira Pharma'},
#  {'label': 'ORG', 'pattern': 'Alterity Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Autohome'},
#  {'label': 'ORG', 'pattern': 'Athena Technology Acquisition'},
#  {'label': 'ORG', 'pattern': 'Athersys'},
#  {'label': 'ORG', 'pattern': 'Allegheny Technologies'},
#  {'label': 'ORG', 'pattern': 'ATIF Holdings'},
#  {'label': 'ORG', 'pattern': 'ATI Physical Therapy'},
#  {'label': 'ORG', 'pattern': 'Atkore International Group'},
#  {'label': 'ORG', 'pattern': 'Atlanticus Holdings'},
#  {'label': 'ORG', 'pattern': 'Ames National'},
#  {'label': 'ORG', 'pattern': 'Altimar Acquisition II'},
#  {'label': 'ORG', 'pattern': '180 Life Sciences'},
#  {'label': 'ORG', 'pattern': 'ATN International'},
#  {'label': 'ORG', 'pattern': 'Actinium Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Athenex'},
#  {'label': 'ORG', 'pattern': 'Atmos Energy'},
#  {'label': 'ORG', 'pattern': 'Atomera'},
#  {'label': 'ORG', 'pattern': 'Atossa Therapeutics'},
#  {'label': 'ORG', 'pattern': 'AptarGroup'},
#  {'label': 'ORG', 'pattern': 'Atara Biotherapeutics'},
#  {'label': 'ORG', 'pattern': 'AtriCure'},
#  {'label': 'ORG', 'pattern': 'Atrion Corporation'},
#  {'label': 'ORG', 'pattern': 'Astronics Corporation'},
#  {'label': 'ORG', 'pattern': 'Antares Pharma'},
#  {'label': 'ORG', 'pattern': 'Air Transport Services Group'},
#  {'label': 'ORG', 'pattern': 'Atento'},
#  {'label': 'ORG', 'pattern': 'Altice USA'},
#  {'label': 'ORG', 'pattern': 'Tribe Capital Growth I'},
#  {'label': 'ORG', 'pattern': 'Activision Blizzard'},
#  {'label': 'ORG', 'pattern': 'Avenue Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Astria Therapeutics'},
#  {'label': 'ORG', 'pattern': 'AcuityAds'},
#  {'label': 'ORG', 'pattern': 'AngloGold Ashanti'},
#  {'label': 'ORG', 'pattern': 'Atlantic Union Bankshares'},
#  {'label': 'ORG', 'pattern': 'Auburn National Bancorporation'},
#  {'label': 'ORG', 'pattern': 'Audacy'},
#  {'label': 'ORG', 'pattern': 'AudioCodes'},
#  {'label': 'ORG', 'pattern': 'Ipsidy'},
#  {'label': 'ORG', 'pattern': 'Golden Minerals'},
#  {'label': 'ORG', 'pattern': 'Aurinia Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Aurora Acquisition'},
#  {'label': 'ORG', 'pattern': 'Austerlitz Acquisition I'},
#  {'label': 'ORG', 'pattern': 'Autolus Therapeutics'},
#  {'label': 'ORG', 'pattern': 'AutoWeb'},
#  {'label': 'ORG', 'pattern': 'Auddia'},
#  {'label': 'ORG', 'pattern': 'Applied UV'},
#  {'label': 'ORG', 'pattern': 'Yamana Gold'},
#  {'label': 'ORG', 'pattern': 'Avista'},
#  {'label': 'ORG', 'pattern': 'Aveanna Healthcare Holdings'},
#  {'label': 'ORG', 'pattern': 'Grupo Aval Acciones y Valores'},
#  {'label': 'ORG', 'pattern': 'Avanti Acquisition'},
#  {'label': 'ORG', 'pattern': 'AeroVironment'},
#  {'label': 'ORG', 'pattern': 'AvalonBay Communities'},
#  {'label': 'ORG', 'pattern': 'Avalon GloboCare'},
#  {'label': 'ORG', 'pattern': 'American Virtual Cloud Technologies'},
#  {'label': 'ORG', 'pattern': 'American Vanguard'},
#  {'label': 'ORG', 'pattern': 'Avadel Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'AVEO Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Broadcom'},
#  {'label': 'ORG', 'pattern': 'Avinger'},
#  {'label': 'ORG', 'pattern': 'Avid Technology'},
#  {'label': 'ORG', 'pattern': 'Atea Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Avalara'},
#  {'label': 'ORG', 'pattern': 'Avanos Medical'},
#  {'label': 'ORG', 'pattern': 'Avient'},
#  {'label': 'ORG', 'pattern': 'Aviat Networks'},
#  {'label': 'ORG', 'pattern': 'Mission Produce'},
#  {'label': 'ORG', 'pattern': 'AvePoint'},
#  {'label': 'ORG', 'pattern': 'Avrobio'},
#  {'label': 'ORG', 'pattern': 'Avnet'},
#  {'label': 'ORG', 'pattern': 'Aerovate Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Avantor'},
#  {'label': 'ORG', 'pattern': 'Avalo Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Anavex Life Sciences'},
#  {'label': 'ORG', 'pattern': 'Avery Dennison'},
#  {'label': 'ORG', 'pattern': 'Avaya Holdings'},
#  {'label': 'ORG', 'pattern': "Aspira Women's Health"},
#  {'label': 'ORG', 'pattern': 'Armstrong World Industries'},
#  {'label': 'ORG', 'pattern': 'American Water Works'},
#  {'label': 'ORG', 'pattern': 'American States Water'},
#  {'label': 'ORG', 'pattern': 'Aware'},
#  {'label': 'ORG', 'pattern': 'Avalon Holdings'},
#  {'label': 'ORG', 'pattern': 'Axos Financial'},
#  {'label': 'ORG', 'pattern': 'Accelerate Diagnostics'},
#  {'label': 'ORG', 'pattern': 'Axogen'},
#  {'label': 'ORG', 'pattern': 'American Axle & Manufacturing'},
#  {'label': 'ORG', 'pattern': 'Axcella Health'},
#  {'label': 'ORG', 'pattern': 'Axonics Modulation Technologies'},
#  {'label': 'ORG', 'pattern': 'Axon Enterprise'},
#  {'label': 'ORG', 'pattern': 'American Express'},
#  {'label': 'ORG', 'pattern': 'AMREP Corporation'},
#  {'label': 'ORG', 'pattern': 'AXIS Capital Holdings'},
#  {'label': 'ORG', 'pattern': 'Axsome Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Axalta Coating Systems'},
#  {'label': 'ORG', 'pattern': 'AXT Inc.'},
#  {'label': 'ORG', 'pattern': 'Alexco Resource'},
#  {'label': 'ORG', 'pattern': 'Atlantica Sustainable Infrastructure'},
#  {'label': 'ORG', 'pattern': 'Acuity Brands'},
#  {'label': 'ORG', 'pattern': 'Ayala Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'AYRO, Inc.'},
#  {'label': 'ORG', 'pattern': 'Aytu BioScience'},
#  {'label': 'ORG', 'pattern': 'Alteryx'},
#  {'label': 'ORG', 'pattern': 'AZEK Company'},
#  {'label': 'ORG', 'pattern': 'AstraZeneca'},
#  {'label': 'ORG', 'pattern': 'AutoZone'},
#  {'label': 'ORG', 'pattern': 'Aspen Technology'},
#  {'label': 'ORG', 'pattern': 'Azure Power Global'},
#  {'label': 'ORG', 'pattern': 'AzurRx BioPharma'},
#  {'label': 'ORG', 'pattern': 'Azul S.A.'},
#  {'label': 'ORG', 'pattern': 'Aziyo Biologics'},
#  {'label': 'ORG', 'pattern': 'AZZ Inc.'},
#  {'label': 'ORG', 'pattern': 'Barnes Group'},
#  {'label': 'ORG', 'pattern': 'Boeing'},
#  {'label': 'ORG', 'pattern': 'Alibaba Group'},
#  {'label': 'ORG', 'pattern': 'Bank of America'},
#  {'label': 'ORG', 'pattern': 'Booz Allen Hamilton'},
#  {'label': 'ORG', 'pattern': 'Braskem'},
#  {'label': 'ORG', 'pattern': "Bally's Corporation"},
#  {'label': 'ORG', 'pattern': 'Brookfield Asset Management'},
#  {'label': 'ORG', 'pattern': 'Banc of California'},
#  {'label': 'ORG', 'pattern': 'Bandwidth'},
#  {'label': 'ORG', 'pattern': 'BancFirst Corporation'},
#  {'label': 'ORG', 'pattern': 'Banner Corporation'},
#  {'label': 'ORG', 'pattern': 'StoneCastle Financial'},
#  {'label': 'ORG', 'pattern': 'Baosheng Media Group'},
#  {'label': 'ORG', 'pattern': 'Credicorp'},
#  {'label': 'ORG', 'pattern': 'The Original BARK Company'},
#  {'label': 'ORG', 'pattern': 'Couchbase'},
#  {'label': 'ORG', 'pattern': 'Battalion Oil'},
#  {'label': 'ORG', 'pattern': 'Baxter International'},
#  {'label': 'ORG', 'pattern': 'BlackBerry'},
#  {'label': 'ORG', 'pattern': 'Banco BBVA Argentina'},
#  {'label': 'ORG', 'pattern': 'Bed Bath & Beyond'},
#  {'label': 'ORG', 'pattern': 'Concrete Pumping Holdings'},
#  {'label': 'ORG', 'pattern': 'Banco Bradesco'},
#  {'label': 'ORG', 'pattern': 'Barings BDC'},
#  {'label': 'ORG', 'pattern': 'Beasley Broadcast Group'},
#  {'label': 'ORG', 'pattern': 'Brickell Biotech'},
#  {'label': 'ORG', 'pattern': 'Vinco Ventures'},
#  {'label': 'ORG', 'pattern': 'BridgeBio Pharma'},
#  {'label': 'ORG', 'pattern': 'BHP Group'},
#  {'label': 'ORG', 'pattern': 'BBQ Holdings'},
#  {'label': 'ORG', 'pattern': 'Barrett Business Services'},
#  {'label': 'ORG', 'pattern': 'Brookfield Business Partners'},
#  {'label': 'ORG', 'pattern': 'Banco Bilbao Vizcaya Argentaria'},
#  {'label': 'ORG', 'pattern': 'Build-A-Bear Workshop'},
#  {'label': 'ORG', 'pattern': 'Bath & Body Works'},
#  {'label': 'ORG', 'pattern': 'Best Buy'},
#  {'label': 'ORG', 'pattern': 'Brunswick'},
#  {'label': 'ORG', 'pattern': 'BioAtla'},
#  {'label': 'ORG', 'pattern': 'Brookline Capital Acquisition'},
#  {'label': 'ORG', 'pattern': 'BCB Bancorp'},
#  {'label': 'ORG', 'pattern': 'Boise Cascade'},
#  {'label': 'ORG', 'pattern': 'BioCardia'},
#  {'label': 'ORG', 'pattern': 'BCE, Inc.'},
#  {'label': 'ORG', 'pattern': 'Bonanza Creek Energy'},
#  {'label': 'ORG', 'pattern': 'Atreca'},
#  {'label': 'ORG', 'pattern': 'Banco de Chile SA'},
#  {'label': 'ORG', 'pattern': 'Brainstorm Cell Therapeutics'},
#  {'label': 'ORG', 'pattern': 'BayCom'},
#  {'label': 'ORG', 'pattern': "Brink's Company"},
#  {'label': 'ORG', 'pattern': 'Blucora'},
#  {'label': 'ORG', 'pattern': 'Brightcove'},
#  {'label': 'ORG', 'pattern': '1895 Bancorp of Wisconsin'},
#  {'label': 'ORG', 'pattern': 'Balchem Corporation'},
#  {'label': 'ORG', 'pattern': 'BioCryst Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Barclays'},
#  {'label': 'ORG', 'pattern': 'Bain Capital'},
#  {'label': 'ORG', 'pattern': 'BriaCell Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Bicycle Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Big Cypress Acquisition'},
#  {'label': 'ORG', 'pattern': 'Belden'},
#  {'label': 'ORG', 'pattern': "Flanigan's Enterprises"},
#  {'label': 'ORG', 'pattern': 'Brandywine Realty Trust'},
#  {'label': 'ORG', 'pattern': 'Blonder Tongue Laboratories'},
#  {'label': 'ORG', 'pattern': 'BioDelivery Sciences'},
#  {'label': 'ORG', 'pattern': 'Biodesix'},
#  {'label': 'ORG', 'pattern': 'Black Diamond Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Becton, Dickinson'},
#  {'label': 'ORG', 'pattern': 'Bloom Energy'},
#  {'label': 'ORG', 'pattern': 'Beam Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Beacon Roofing Supply'},
#  {'label': 'ORG', 'pattern': 'Bright Scholar Education'},
#  {'label': 'ORG', 'pattern': 'Beam Global'},
#  {'label': 'ORG', 'pattern': 'KE Holdings'},
#  {'label': 'ORG', 'pattern': 'Bel Fuse'},
#  {'label': 'ORG', 'pattern': 'Franklin Resources'},
#  {'label': 'ORG', 'pattern': 'Benessere Capital Acquisition'},
#  {'label': 'ORG', 'pattern': 'Brookfield Renewable Partners'},
#  {'label': 'ORG', 'pattern': 'Brookfield Renewable Corporation'},
#  {'label': 'ORG', 'pattern': 'Berry Global Group'},
#  {'label': 'ORG', 'pattern': 'BEST Inc.'},
#  {'label': 'ORG', 'pattern': 'Brown-Forman'},
#  {'label': 'ORG', 'pattern': 'Bright Horizons Family Solutions'},
#  {'label': 'ORG', 'pattern': 'Bank First'},
#  {'label': 'ORG', 'pattern': 'BurgerFi International'},
#  {'label': 'ORG', 'pattern': 'BankFinancial Corporation'},
#  {'label': 'ORG', 'pattern': 'Butterfly Network'},
#  {'label': 'ORG', 'pattern': 'Biofrontera AG'},
#  {'label': 'ORG', 'pattern': 'Saul Centers'},
#  {'label': 'ORG', 'pattern': 'Business First Bancshares'},
#  {'label': 'ORG', 'pattern': 'Bunge'},
#  {'label': 'ORG', 'pattern': 'BGC Partners'},
#  {'label': 'ORG', 'pattern': 'Big 5 Sporting Goods'},
#  {'label': 'ORG', 'pattern': 'Birks Group'},
#  {'label': 'ORG', 'pattern': 'BeiGene'},
#  {'label': 'ORG', 'pattern': 'Berkshire Grey'},
#  {'label': 'ORG', 'pattern': 'B&G Foods'},
#  {'label': 'ORG', 'pattern': 'BG Staffing'},
#  {'label': 'ORG', 'pattern': 'Build Acquisition'},
#  {'label': 'ORG', 'pattern': 'Biglari Holdings'},
#  {'label': 'ORG', 'pattern': 'Blue Hat Interactive'},
#  {'label': 'ORG', 'pattern': 'Bar Harbor Bankshares'},
#  {'label': 'ORG', 'pattern': 'Bausch Health Companies'},
#  {'label': 'ORG', 'pattern': 'Benchmark Electronics'},
#  {'label': 'ORG', 'pattern': 'Brighthouse Financial'},
#  {'label': 'ORG', 'pattern': 'Bright Health Group'},
#  {'label': 'ORG', 'pattern': 'Berkshire Hills Bancorp'},
#  {'label': 'ORG', 'pattern': 'Braemar Hotels & Resorts'},
#  {'label': 'ORG', 'pattern': 'Bull Horn Holdings'},
#  {'label': 'ORG', 'pattern': 'BioHiTech Global'},
#  {'label': 'ORG', 'pattern': 'Biohaven Pharmaceutical'},
#  {'label': 'ORG', 'pattern': 'Baidu, Inc'},
#  {'label': 'ORG', 'pattern': 'Big Lots'},
#  {'label': 'ORG', 'pattern': 'BigCommerce'},
#  {'label': 'ORG', 'pattern': 'Biogen'},
#  {'label': 'ORG', 'pattern': 'Bilibili'},
#  {'label': 'ORG', 'pattern': 'Bill.com'},
#  {'label': 'ORG', 'pattern': 'BIMI International Medical'},
#  {'label': 'ORG', 'pattern': 'Bio-Rad Laboratories'},
#  {'label': 'ORG', 'pattern': 'Biocept'},
#  {'label': 'ORG', 'pattern': 'BIOLASE, Inc.'},
#  {'label': 'ORG', 'pattern': 'Biotech Acquisition'},
#  {'label': 'ORG', 'pattern': 'Bioceres Crop Solutions'},
#  {'label': 'ORG', 'pattern': 'Brookfield Infrastructure Partners'},
#  {'label': 'ORG', 'pattern': 'Brookfield Infrastructure'},
#  {'label': 'ORG', 'pattern': 'Bite Acquisition'},
#  {'label': 'ORG', 'pattern': 'Bitfarms'},
#  {'label': 'ORG', 'pattern': 'BioVie'},
#  {'label': 'ORG', 'pattern': "BJ's Wholesale Club"},
#  {'label': 'ORG', 'pattern': "BJ's Restaurants"},
#  {'label': 'ORG', 'pattern': 'Bank of New York Mellon'},
#  {'label': 'ORG', 'pattern': 'BlackRock Capital Investment'},
#  {'label': 'ORG', 'pattern': 'Brookdale Senior Living'},
#  {'label': 'ORG', 'pattern': 'The Buckle'},
#  {'label': 'ORG', 'pattern': 'BlueKnight Energy Partners'},
#  {'label': 'ORG', 'pattern': 'Black Hills'},
#  {'label': 'ORG', 'pattern': 'Black Knight'},
#  {'label': 'ORG', 'pattern': 'Booking Holdings'},
#  {'label': 'ORG', 'pattern': 'Baker Hughes'},
#  {'label': 'ORG', 'pattern': 'Bank of South Carolina'},
#  {'label': 'ORG', 'pattern': 'BlackSky Technology'},
#  {'label': 'ORG', 'pattern': 'BK Technologies'},
#  {'label': 'ORG', 'pattern': 'BankUnited'},
#  {'label': 'ORG', 'pattern': 'BIO-key International'},
#  {'label': 'ORG', 'pattern': 'BlackLine'},
#  {'label': 'ORG', 'pattern': 'Blue Bird'},
#  {'label': 'ORG', 'pattern': 'Bellicum Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'BlueCity Holdings'},
#  {'label': 'ORG', 'pattern': 'TopBuild'},
#  {'label': 'ORG', 'pattern': 'Blade Air Mobility'},
#  {'label': 'ORG', 'pattern': 'Ballard Power Systems'},
#  {'label': 'ORG', 'pattern': 'Builders FirstSource'},
#  {'label': 'ORG', 'pattern': 'BioLife Solutions'},
#  {'label': 'ORG', 'pattern': 'Blue Foundry Bancorp'},
#  {'label': 'ORG', 'pattern': 'Berkeley Lights'},
#  {'label': 'ORG', 'pattern': 'Bridgeline Digital'},
#  {'label': 'ORG', 'pattern': 'BlackRock'},
#  {'label': 'ORG', 'pattern': 'Blackbaud'},
#  {'label': 'ORG', 'pattern': 'Ball Corporation'},
#  {'label': 'ORG', 'pattern': "Bloomin' Brands"},
#  {'label': 'ORG', 'pattern': 'Blend Labs'},
#  {'label': 'ORG', 'pattern': 'Blink Charging'},
#  {'label': 'ORG', 'pattern': 'Bellerophon Therapeutics'},
#  {'label': 'ORG', 'pattern': 'BioLineRx'},
#  {'label': 'ORG', 'pattern': 'BCLS Acquisition'},
#  {'label': 'ORG', 'pattern': 'Bright Lights Acquisition'},
#  {'label': 'ORG', 'pattern': 'BELLUS Health'},
#  {'label': 'ORG', 'pattern': 'BlueRiver Acquisition'},
#  {'label': 'ORG', 'pattern': 'Bluebird Bio'},
#  {'label': 'ORG', 'pattern': 'Banco Latinoamericano'},
#  {'label': 'ORG', 'pattern': 'Banco Macro'},
#  {'label': 'ORG', 'pattern': 'Bumble'},
#  {'label': 'ORG', 'pattern': 'Biomea Fusion'},
#  {'label': 'ORG', 'pattern': 'Badger Meter'},
#  {'label': 'ORG', 'pattern': 'Bank of Montreal'},
#  {'label': 'ORG', 'pattern': 'Biomerica'},
#  {'label': 'ORG', 'pattern': 'Bank of Marin Bancorp'},
#  {'label': 'ORG', 'pattern': 'BioMarin Pharmaceutical'},
#  {'label': 'ORG', 'pattern': 'Bryn Mawr Bank'},
#  {'label': 'ORG', 'pattern': 'BM Technologies'},
#  {'label': 'ORG', 'pattern': 'Bristol-Myers Squibb'},
#  {'label': 'ORG', 'pattern': 'Barnes & Noble Education'},
#  {'label': 'ORG', 'pattern': 'Benefitfocus'},
#  {'label': 'ORG', 'pattern': 'BioNano Genomics'},
#  {'label': 'ORG', 'pattern': 'Broadstone Net Lease'},
#  {'label': 'ORG', 'pattern': 'Burning Rock Biotech'},
#  {'label': 'ORG', 'pattern': 'Bank of Nova Scotia'},
#  {'label': 'ORG', 'pattern': 'Bonso Electronics International'},
#  {'label': 'ORG', 'pattern': 'Benitec Biopharma'},
#  {'label': 'ORG', 'pattern': 'BioNTech SE'},
#  {'label': 'ORG', 'pattern': 'Bluescape Opportunities Acquisition'},
#  {'label': 'ORG', 'pattern': 'BOA Acquisition'},
#  {'label': 'ORG', 'pattern': 'Bank of Commerce Holdings'},
#  {'label': 'ORG', 'pattern': 'Beachbody'},
#  {'label': 'ORG', 'pattern': 'Bank of Hawaii'},
#  {'label': 'ORG', 'pattern': 'BOK Financial'},
#  {'label': 'ORG', 'pattern': 'Bolt Biotherapeutics'},
#  {'label': 'ORG', 'pattern': 'Boston Omaha'},
#  {'label': 'ORG', 'pattern': 'Bon Natural Life'},
#  {'label': 'ORG', 'pattern': 'DMC Global'},
#  {'label': 'ORG', 'pattern': 'Boot Barn Holdings'},
#  {'label': 'ORG', 'pattern': 'Borr Drilling'},
#  {'label': 'ORG', 'pattern': 'BOS Better Online Solutions'},
#  {'label': 'ORG', 'pattern': 'Bank of the James Financial'},
#  {'label': 'ORG', 'pattern': 'BowX Acquisition'},
#  {'label': 'ORG', 'pattern': 'Box, Inc.'},
#  {'label': 'ORG', 'pattern': 'Boxlight'},
#  {'label': 'ORG', 'pattern': 'BP plc'},
#  {'label': 'ORG', 'pattern': 'Blueprint Medicines'},
#  {'label': 'ORG', 'pattern': 'BP Midstream Partners'},
#  {'label': 'ORG', 'pattern': 'Popular'},
#  {'label': 'ORG', 'pattern': 'Bank of Princeton'},
#  {'label': 'ORG', 'pattern': 'BP Prudhoe Bay Royalty Trust'},
#  {'label': 'ORG', 'pattern': 'Bio-Path Holdings'},
#  {'label': 'ORG', 'pattern': 'Biophytis'},
#  {'label': 'ORG', 'pattern': 'Boqii Holding'},
#  {'label': 'ORG', 'pattern': 'Broadridge Financial Solutions'},
#  {'label': 'ORG', 'pattern': 'Bragg Gaming Group'},
#  {'label': 'ORG', 'pattern': 'Bellring Brands'},
#  {'label': 'ORG', 'pattern': 'Blue Ridge Bankshares'},
#  {'label': 'ORG', 'pattern': 'Brady Corporation'},
#  {'label': 'ORG', 'pattern': 'Burcon NutraScience'},
#  {'label': 'ORG', 'pattern': 'Bridge Investment Group'},
#  {'label': 'ORG', 'pattern': 'Breeze Holdings Acquisition'},
#  {'label': 'ORG', 'pattern': 'BRF S.A.'},
#  {'label': 'ORG', 'pattern': 'Bluerock Residential Growth REIT'},
#  {'label': 'ORG', 'pattern': 'Bridgford Foods'},
#  {'label': 'ORG', 'pattern': 'B. Riley Principal 250 Merger'},
#  {'label': 'ORG', 'pattern': 'Berkshire Hathaway'},
#  {'label': 'ORG', 'pattern': 'Brookline Bancorp'},
#  {'label': 'ORG', 'pattern': 'Bruker'},
#  {'label': 'ORG', 'pattern': 'Brooks Automation'},
#  {'label': 'ORG', 'pattern': 'Brilliant Acquisition'},
#  {'label': 'ORG', 'pattern': 'Broadmark Realty Capital'},
#  {'label': 'ORG', 'pattern': 'Barnwell Industries'},
#  {'label': 'ORG', 'pattern': 'Brown & Brown'},
#  {'label': 'ORG', 'pattern': 'Brooge Energy'},
#  {'label': 'ORG', 'pattern': 'BRP Group'},
#  {'label': 'ORG', 'pattern': 'B. Riley Principal 150 Merger'},
#  {'label': 'ORG', 'pattern': 'Borqs Technologies'},
#  {'label': 'ORG', 'pattern': 'BrightSpire Capital'},
#  {'label': 'ORG', 'pattern': 'BRT Apartments'},
#  {'label': 'ORG', 'pattern': 'Brixmor Property Group'},
#  {'label': 'ORG', 'pattern': 'Berry Corporation'},
#  {'label': 'ORG', 'pattern': 'Banco Santander-Chile'},
#  {'label': 'ORG', 'pattern': 'Bogota Financial'},
#  {'label': 'ORG', 'pattern': 'Banco Santander Brasil'},
#  {'label': 'ORG', 'pattern': 'Bassett Furniture Industries'},
#  {'label': 'ORG', 'pattern': 'Blue Safari Group Acquisition'},
#  {'label': 'ORG', 'pattern': 'BioSig Technologies'},
#  {'label': 'ORG', 'pattern': 'BrightSphere Investment Group'},
#  {'label': 'ORG', 'pattern': 'Big Sky Growth Partners'},
#  {'label': 'ORG', 'pattern': 'Black Stone Minerals'},
#  {'label': 'ORG', 'pattern': 'Banco Santander Mexico'},
#  {'label': 'ORG', 'pattern': 'Broadstone Acquisition'},
#  {'label': 'ORG', 'pattern': 'Bsquare Corporation'},
#  {'label': 'ORG', 'pattern': 'Sierra Bancorp'},
#  {'label': 'ORG', 'pattern': 'Bank7 Corp.'},
#  {'label': 'ORG', 'pattern': 'Boston Scientific'},
#  {'label': 'ORG', 'pattern': 'Bentley Systems'},
#  {'label': 'ORG', 'pattern': 'BioXcel Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Burgundy Technology Acquisition'},
#  {'label': 'ORG', 'pattern': 'Bit Brother'},
#  {'label': 'ORG', 'pattern': 'Bit Digital'},
#  {'label': 'ORG', 'pattern': 'BIT Mining'},
#  {'label': 'ORG', 'pattern': 'Biotricity'},
#  {'label': 'ORG', 'pattern': 'B2Gold'},
#  {'label': 'ORG', 'pattern': 'British American Tobacco'},
#  {'label': 'ORG', 'pattern': 'Ballantyne Strong'},
#  {'label': 'ORG', 'pattern': 'Bridgetown 2 Holdings'},
#  {'label': 'ORG', 'pattern': 'BTRS Holdings'},
#  {'label': 'ORG', 'pattern': 'Better Choice Company'},
#  {'label': 'ORG', 'pattern': 'Peabody Energy'},
#  {'label': 'ORG', 'pattern': 'Bridgetown Holdings'},
#  {'label': 'ORG', 'pattern': 'Brooklyn ImmunoTherapeutics'},
#  {'label': 'ORG', 'pattern': 'Anheuser-Busch InBev'},
#  {'label': 'ORG', 'pattern': 'Burford Capital'},
#  {'label': 'ORG', 'pattern': 'Burlington Stores'},
#  {'label': 'ORG', 'pattern': 'First Busey'},
#  {'label': 'ORG', 'pattern': 'BrightView Holdings'},
#  {'label': 'ORG', 'pattern': 'Bluegreen Vacations'},
#  {'label': 'ORG', 'pattern': 'Compania de Minas Buenaventura'},
#  {'label': 'ORG', 'pattern': 'Bioventus'},
#  {'label': 'ORG', 'pattern': 'BiondVax Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Babcock & Wilcox Enterprises'},
#  {'label': 'ORG', 'pattern': 'BorgWarner'},
#  {'label': 'ORG', 'pattern': 'Better World Acquisition'},
#  {'label': 'ORG', 'pattern': 'Brainsway'},
#  {'label': 'ORG', 'pattern': 'Bridgewater Bancshares'},
#  {'label': 'ORG', 'pattern': 'Broadwind Energy'},
#  {'label': 'ORG', 'pattern': 'Bankwell Financial Group'},
#  {'label': 'ORG', 'pattern': 'Bowman Consulting Group'},
#  {'label': 'ORG', 'pattern': 'Betterware de Mexico'},
#  {'label': 'ORG', 'pattern': 'BWX Technologies'},
#  {'label': 'ORG', 'pattern': 'Blackstone Group'},
#  {'label': 'ORG', 'pattern': 'BlueLinx Holdings'},
#  {'label': 'ORG', 'pattern': 'Blackstone Mortgage Trust'},
#  {'label': 'ORG', 'pattern': 'Boston Properties'},
#  {'label': 'ORG', 'pattern': 'Baudax Bio'},
#  {'label': 'ORG', 'pattern': 'BancorpSouth Bank'},
#  {'label': 'ORG', 'pattern': 'Byline Bancorp'},
#  {'label': 'ORG', 'pattern': 'Boyd Gaming'},
#  {'label': 'ORG', 'pattern': 'Broadway Financial'},
#  {'label': 'ORG', 'pattern': 'Beyond Meat'},
#  {'label': 'ORG', 'pattern': 'Byrna Technologies'},
#  {'label': 'ORG', 'pattern': 'BeyondSpring'},
#  {'label': 'ORG', 'pattern': 'BYTE Acquisition'},
#  {'label': 'ORG', 'pattern': 'Kanzhun'},
#  {'label': 'ORG', 'pattern': 'Beazer Homes USA'},
#  {'label': 'ORG', 'pattern': 'Baozun'},
#  {'label': 'ORG', 'pattern': 'Citigroup'},
#  {'label': 'ORG', 'pattern': 'Corporacion America Airports'},
#  {'label': 'ORG', 'pattern': 'China Automotive Systems'},
#  {'label': 'ORG', 'pattern': 'Cabaletta Bio'},
#  {'label': 'ORG', 'pattern': 'Cable One'},
#  {'label': 'ORG', 'pattern': 'Camden National'},
#  {'label': 'ORG', 'pattern': 'Credit Acceptance'},
#  {'label': 'ORG', 'pattern': 'CACI International'},
#  {'label': 'ORG', 'pattern': 'Cadence Bancorporation'},
#  {'label': 'ORG', 'pattern': 'Candel Therapeutics'},
#  {'label': 'ORG', 'pattern': 'CAE Inc.'},
#  {'label': 'ORG', 'pattern': 'Conagra Brands'},
#  {'label': 'ORG', 'pattern': 'Cardinal Health'},
#  {'label': 'ORG', 'pattern': 'CA Healthcare Acquisition'},
#  {'label': 'ORG', 'pattern': 'CAI International'},
#  {'label': 'ORG', 'pattern': 'Canon'},
#  {'label': 'ORG', 'pattern': 'Cheesecake Factory'},
#  {'label': 'ORG', 'pattern': 'Caleres'},
#  {'label': 'ORG', 'pattern': 'Calithera Biosciences'},
#  {'label': 'ORG', 'pattern': 'California BanCorp'},
#  {'label': 'ORG', 'pattern': 'Cal-Maine Foods'},
#  {'label': 'ORG', 'pattern': 'Calliditas Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Calix, Inc.'},
#  {'label': 'ORG', 'pattern': 'CalAmp'},
#  {'label': 'ORG', 'pattern': 'Camtek'},
#  {'label': 'ORG', 'pattern': 'Canaan'},
#  {'label': 'ORG', 'pattern': 'Can-Fite BioPharma'},
#  {'label': 'ORG', 'pattern': 'Cango Inc.'},
#  {'label': 'ORG', 'pattern': 'Cano Health'},
#  {'label': 'ORG', 'pattern': 'CrossAmerica Partners'},
#  {'label': 'ORG', 'pattern': 'Capricor Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Avis Budget Group'},
#  {'label': 'ORG', 'pattern': 'Cara Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Carter Bankshares'},
#  {'label': 'ORG', 'pattern': 'Cargurus'},
#  {'label': 'ORG', 'pattern': 'Carrier Global'},
#  {'label': 'ORG', 'pattern': 'Cars.com'},
#  {'label': 'ORG', 'pattern': 'Carver Bancorp'},
#  {'label': 'ORG', 'pattern': 'Cascade Acquisition'},
#  {'label': 'ORG', 'pattern': 'Casa Systems'},
#  {'label': 'ORG', 'pattern': 'Meta Financial Group'},
#  {'label': 'ORG', 'pattern': 'CASI Pharmaceuticals'},
#  {'label': 'ORG', 'pattern': 'Cass Information Systems'},
#  {'label': 'ORG', 'pattern': "Casey's General Stores"},
#  {'label': 'ORG', 'pattern': 'Caterpillar'},
#  {'label': 'ORG', 'pattern': 'Cambridge Bancorp'},
#  {'label': 'ORG', 'pattern': 'Cato Corporation'},
#  {'label': 'ORG', 'pattern': 'Cathay General Bancorp'},
#  {'label': 'ORG', 'pattern': 'Chubb'},
#  {'label': 'ORG', 'pattern': 'CBRE Acquisition'},
#  {'label': 'ORG', 'pattern': 'Colony Bankcorp'},
#  {'label': 'ORG', 'pattern': 'CBAK Energy Technology'},
#  {'label': 'ORG', 'pattern': 'CymaBay Therapeutics'},
#  {'label': 'ORG', 'pattern': 'Companhia Brasileira de Distribuicao'},
#  {'label': 'ORG', 'pattern': 'CB Financial Services'},
#  {'label': 'ORG', 'pattern': 'Catalyst Biosciences'},
#  {'label': 'ORG', 'pattern': 'CBM Bancorp'},
#  {'label': 'ORG', 'pattern': 'Capital Bancorp'},
#  {'label': 'ORG', 'pattern': 'Cboe Global Markets'},
#  {'label': 'ORG', 'pattern': 'CBRE Group'},
#  {'label': 'ORG', 'pattern': 'Cracker Barrel'},
#  {'label': 'ORG', 'pattern': 'Commerce Bancshares'},
#  {'label': 'ORG', 'pattern': 'Cabot Corporation'},
#  {'label': 'ORG', 'pattern': 'CBTX, Inc.'},
#  {'label': 'ORG', 'pattern': 'Community Bank System'},
#  {'label': 'ORG', 'pattern': 'CBIZ, Inc.'},
#  {'label': 'ORG', 'pattern': 'Chemours Company'},
#  {'label': 'ORG', 'pattern': 'CITIC Capital Acquisition'},
#  {'label': 'ORG', 'pattern': 'Crescent Capital BDC'},
#  {'label': 'ORG', 'pattern': 'Coastal Financial'},
#  {'label': 'ORG', 'pattern': 'Capital City Bank Group'},
#  {'label': 'ORG', 'pattern': 'C4 Therapeutics'},
#  {'label': 'ORG', 'pattern': 'CCC Intelligent Solutions'},
#  {'label': 'ORG', 'pattern': 'Cryo-Cell International'},
#  {'label': 'ORG', 'pattern': 'Coca-Cola European Partners'},
#  {'label': 'ORG', 'pattern': 'Chase Corporation'},
#  {'label': 'ORG', 'pattern': 'Crown Castle'},
#  {'label': 'ORG', 'pattern': 'Cameco'},
#  {'label': 'ORG', 'pattern': 'Crown Holdings'},
#  {'label': 'ORG', 'pattern': 'Carnival'},
#  {'label': 'ORG', 'pattern': 'CSI Compressco'},
#  {'label': 'ORG', 'pattern': 'Concord Medical Services'},
#  {'label': 'ORG', 'pattern': 'CMC Materials'},
#  {'label': 'ORG', 'pattern': 'Code Chain New Continent'},
#  {'label': 'ORG', 'pattern': 'CNB Financial'},
#  {'label': 'ORG', 'pattern': 'Clear Channel Outdoor'},
#  {'label': 'ORG', 'pattern': 'Cogent Communications Holdings'},
#  {'label': 'ORG', 'pattern': 'Cross Country Healthcare'},
#  {'label': 'ORG', 'pattern': 'Century Communities'},
#  {'label': 'ORG', 'pattern': 'Cia Cervecerias Unidas'},
#  {'label': 'ORG', 'pattern': 'Churchill Capital V'},
#  {'label': 'ORG', 'pattern': 'Churchill Capital VI'},
#  {'label': 'ORG', 'pattern': 'ChemoCentryx'},
#  {'label': 'ORG', 'pattern': 'Chindata Group'},
#  {'label': 'ORG', 'pattern': 'Codiak BioSciences'},
#  {'label': 'ORG', 'pattern': 'Ceridian HCM Holding'},
#  {'label': 'ORG', 'pattern': 'Coeur Mining'},
#  {'label': 'ORG', 'pattern': 'Centennial Resource Development'},
#  {'label': 'ORG', 'pattern': 'CDK Global'},
#  {'label': 'ORG', 'pattern': 'Cardlytics'},
#  {'label': 'ORG', 'pattern': 'Avid Bioservices'},
#  ...]

# %% [markdown]
# ## Step 4: Create an EntityRuler

# %% [markdown]
# - Use a spaCy language model to create an EntityRuler.
# - Add the patterns for both companies and stock symbols to the EntityRuler pipeline.

# %%
import spacy
from spacy.pipeline import EntityRuler
nlp=spacy.load('en_core_web_sm')

# this creates an EntityRuler and adds it to the pipeline
ruler=nlp.add_pipe('entity_ruler', before='ner')
ruler.add_patterns(all_patterns)

# %% [markdown]
# ## Step 5: Test the EntityRuler

# %% [markdown]
# - Will use sample texts, that include references to companies and stock symbols
# - Apply the EntityRuler to the text and check if it correctly identifies the entities

# %%
# I used separate cells for each paragraph so this is for the first paragraph
paragraph1="""Helmerich & Payne (HP) saw its stock rise by 1.5%, fueled by optimistic forecasts in the Energy Equipment & Services sector. In contrast, Check-Cap (CHEK) faced a decline of 2.3% following its announcement of increased costs related to supply chain disruptions.

Meanwhile, Vallon Pharmaceuticals (VLON) gained 0.8% after strong quarterly earnings, outperforming its peers in the Biotechnology space. Sequans Communications (SQNS) also recorded a modest increase of 0.5%, reflecting investors' confidence in its ability to navigate challenges in the Semiconductors & Semiconductor Equipment industry."""


# this applies the NLP pipeline to the first paragraph and then prints the recognized entities for ORG and STOCK
doc=nlp(paragraph1)
for ent in doc.ents:
        if ent.label_ in ('ORG', 'STOCK'):
            print(f"{ent.text} - {ent.label_}")
# Out:
# Helmerich & Payne - ORG
# HP - STOCK
# the Energy Equipment & Services - ORG
# Check-Cap - ORG
# CHEK - STOCK
# Vallon Pharmaceuticals - ORG
# VLON - STOCK
# Biotechnology - ORG
# Sequans Communications - ORG
# SQNS - STOCK
# Semiconductors & Semiconductor Equipment - ORG

# %%
# this is for paragraph 2
paragraph2="""Aemetis (AMTX) saw its stock rise by 1.5%, fueled by optimistic forecasts in the Oil, Gas & Consumable Fuels sector. In contrast, Ferro Corporation (FOE) faced a decline of 2.3% following its announcement of increased costs related to supply chain disruptions.

Meanwhile, RingCentral (RNG) gained 0.8% after strong quarterly earnings, outperforming its peers in the Software space. ACI Worldwide (ACIW) also recorded a modest increase of 0.5%, reflecting investors' confidence in its ability to navigate challenges in the Software industry."""

# this applies the NLP pipeline to the second paragraph and then prints the recognized entities for ORG and STOCK
doc=nlp(paragraph2)
for ent in doc.ents:
        if ent.label_ in ('ORG', 'STOCK'):
            print(f"{ent.text} - {ent.label_}")
# Out:
# Aemetis - ORG
# AMTX - STOCK
# the Oil, Gas & Consumable Fuels - ORG
# Ferro Corporation - ORG
# FOE - STOCK
# RingCentral - ORG
# RNG - STOCK
# Software - ORG
# ACI Worldwide - ORG
# ACIW - STOCK
# Software - ORG

# %%
# this is for paragraph 3
paragraph3="""On a mixed trading day, Par Pacific Holdings (PARR) saw its stock rise by 1.5%, fueled by optimistic forecasts in the Oil, Gas & Consumable Fuels sector. In contrast, Nano Dimension (NNDM) faced a decline of 2.3% following its announcement of increased costs related to supply chain disruptions.

Meanwhile, Beyond Meat (BYND) gained 0.8% after strong quarterly earnings, outperforming its peers in the Food Products space. Apollo Investment (AINV) also recorded a modest increase of 0.5%, reflecting investors' confidence in its ability to navigate challenges in the Capital Markets industry."""

# this applies the NLP pipeline to the third paragraph and then prints the recognized entities for ORG and STOCK
doc=nlp(paragraph3)
for ent in doc.ents:
        if ent.label_ in ('ORG', 'STOCK'):
            print(f"{ent.text} - {ent.label_}")
# Out:
# Par Pacific Holdings - ORG
# PARR - STOCK
# the Oil, Gas & Consumable Fuels - ORG
# Nano Dimension - ORG
# NNDM - STOCK
# Beyond Meat - ORG
# BYND - STOCK
# Food Products - ORG
# Apollo Investment - ORG
# AINV - STOCK
# Capital Markets - ORG
